# %% [markdown]
# # Hayden Island #1 Test Notebook
#
# ### Tony Butzer
#
# ### Referenced Harshu Notebooks
#
# ## Todo
#
# 1. get the bucket prepare script
#     -
# 2. copy to craft when done

# %%
# ! wget https://github.com/opendatacube/datacube-core/blob/index-hackathon/utils/ls_public_bucket.py

# %%
# !datacube --help
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Usage: datacube [OPTIONS] COMMAND [ARGS]...
#
#   Data Cube command-line interface
#
# Options:
#   --version
#   -v, --verbose                   Use multiple times for more verbosity
#   --log-file TEXT                 Specify log file
#   -E, --env TEXT
#   -C, --config, --config_file TEXT
#   --log-queries                   Print database queries.
#   -h, --help                      Show this message and exit.
#
# Commands:
#   dataset        Dataset management commands
#   ingest         Ingest datasets
#   metadata_type  Metadata type commands
#   product        Product commands
#   system         System commands
#   user           User management commands

# %%
# !datacube --version
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Open Data Cube core, version 0+unknown

# %%
# !wget https://github.com/opendatacube/datacube-core/blob/index-hackathon/docs/config_samples/dataset_types/ls_sample_product.yaml
# Out:
# --2018-03-26 13:06:07--  https://github.com/opendatacube/datacube-core/blob/index-hackathon/docs/config_samples/dataset_types/ls_sample_product.yaml
# Resolving github.com (github.com)... 192.30.255.112, 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘ls_sample_product.yaml’
#
# ls_sample_product.y     [ <=>                ] 109.74K  --.-KB/s    in 0.02s
#
# 2018-03-26 13:06:08 (4.70 MB/s) - ‘ls_sample_product.yaml’ saved [112373]

# %%
# !datacube system init
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Initialising database...
# Created.
# Checking indexes/views.
# Done.

# %%
# !datacube product add ls_sample_product.yaml
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Added "ls8_level1"

# %%
# !datacube product list
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
#    name        description                              product_type instrument format   platform
# id
# 1   ls8_level1  Landsat 8 Level 1 Collection-1 OLI-TIRS  level1       OLI_TIRS   GeoTiff  LANDSAT_8

# %%
# !python3 ls_public_bucket.py --help
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Usage: ls_public_bucket.py [OPTIONS] BUCKET_NAME
#
#   Enter Bucket name. Optional to enter configuration file to access a
#   different database
#
# Options:
#   -c, --config PATH  Pass the config file to access the database
#   -p, --prefix TEXT  Pass the prefix of the object to the bucket
#   --help             Show this message and exit.

# %%
# !python3 ls_public_bucket.py landsat-pds -p L8/046/028/
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 2018-03-26 14:51:58,487 INFO Starting new HTTP connection (1): 169.254.169.254
# 2018-03-26 14:51:58,490 INFO Starting new HTTP connection (1): 169.254.169.254
# 2018-03-26 14:51:58,491 INFO Found credentials from IAM Role: tonyEC2
# 2018-03-26 14:51:58,543 INFO Bucket : landsat-pds
# 2018-03-26 14:51:58,547 INFO Calling paginated s3:list_objects with {'Bucket': 'landsat-pds', 'Prefix': 'L8/046/028/'}
# 2018-03-26 14:51:58,549 INFO Starting new HTTPS connection (1): landsat-pds.s3.amazonaws.com
# 2018-03-26 14:51:59,741 INFO Processing L8/046/028/LC80460282013104LGN01/LC80460282013104LGN01_MTL.txt
# ...

# %%
# !datacube dataset search product ='ls8_level1'
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# id: 99bd5c38-2184-5eac-8f67-8fde464b8f14
# product: ls8_level1
# status: active
# locations:
# - http://landsat-pds.s3.amazonaws.com/L8/046/028/LC80460282013104LGN01/LC80460282013104LGN01_MTL.txt
# fields:
#     instrument: OLI_TIRS
#     lat: {begin: 44.99729646958946, end: 47.0331518126554}
#     lon: {begin: -123.85155844271469, end: -120.81980095519165}
#     platform: LANDSAT_8
#     product_type: level1
#     time: {begin: '2013-04-14T18:57:52.232234+00:00', end: '2013-04-14T18:57:52.232234+00:00'}
# ---
# id: 33dae8c1-7b9b-5454-a8ad-70b67d3c5542
# product: ls8_level1
# status: active
# locations:
# ...

# %%
# !datacube dataset search product ='ls8_level1' |grep id |wc
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
#      92     184    3772

# %%
import datacube 
from rasterio.plot import show_hist

# %%
from datetime import datetime

# %%
dc= datacube.Datacube()
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
date_range = (
        datetime(2017,3,12),
        datetime(2017,3,14))

# %%
ds = dc.load(product='ls8_level1',x = (-122.75,-122.65), y =(45.65,45.6),output_crs = 'epsg:32610', resolution = (-30,30),time = date_range, measurements = ('red', 'green', 'blue','nir') )

# %%
ds.all
# Out:
# <bound method ImplementsDatasetReduce._reduce_method.<locals>.wrapped_func of <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*>

# %%
# !datacube dataset search product ='ls8_level1' |grep time
# Out:
# /usr/local/lib/python3.5/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
#     time: {begin: '2013-04-14T18:57:52.232234+00:00', end: '2013-04-14T18:57:52.232234+00:00'}
#     time: {begin: '2013-04-30T18:57:49.954582+00:00', end: '2013-04-30T18:57:49.954582+00:00'}
#     time: {begin: '2013-05-16T18:58:02.238297+00:00', end: '2013-05-16T18:58:02.238297+00:00'}
#     time: {begin: '2013-06-01T18:58:06.187389+00:00', end: '2013-06-01T18:58:06.187389+00:00'}
#     time: {begin: '2013-06-17T18:58:00.052438+00:00', end: '2013-06-17T18:58:00.052438+00:00'}
#     time: {begin: '2013-07-03T18:58:01.904247+00:00', end: '2013-07-03T18:58:01.904247+00:00'}
# ...

# %%
date_range = (
        datetime(2016,3,22),
        datetime(2017,3,24))

# %%
ds = dc.load(product='ls8_level1',x = (-122.65,-122.75), y =(45.59,45.65),output_crs = 'epsg:32610', resolution = (-30,30),time = date_range, measurements = ('red', 'green', 'blue','nir') )

# %%
ds.all
# Out:
# <bound method ImplementsDatasetReduce._reduce_method.<locals>.wrapped_func of <xarray.Dataset>
# Dimensions:  (time: 21, x: 262, y: 224)
# Coordinates:
#   * time     (time) datetime64[ns] 2016-04-06T18:55:41.086494 ...
#   * y        (y) float64 5.055e+06 5.055e+06 5.055e+06 5.055e+06 5.055e+06 ...
#   * x        (x) float64 5.195e+05 5.195e+05 5.195e+05 5.196e+05 5.196e+05 ...
# Data variables:
#     red      (time, y, x) int16 9355 9363 9363 9401 9470 10490 10568 10497 ...
#     green    (time, y, x) int16 10078 10071 10093 10102 10129 10623 10702 ...
#     blue     (time, y, x) int16 11086 11120 11091 11084 11117 11481 11510 ...
#     nir      (time, y, x) int16 10183 10220 10242 10240 10410 11734 12005 ...
# Attributes:
#     crs:      epsg:32610>

# %%
# !pip3 install skimage
# Out:
# ...
#   Using cached skimage-0.0.tar.gz
#     Complete output from command python setup.py egg_info:
#
#     *** Please install the `scikit-image` package (instead of `skimage`) ***
#
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-ua1rrdio/skimage/
# You are using pip version 8.1.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip3 install scikit-image
# Out:
# ...
#     99% |████████████████████████████████| 35.5MB 44.3MB/s eta 0:00:010% |                                | 30kB 3.3MB/s eta 0:00:11    1% |▍                               | 460kB 10.4MB/s eta 0:00:04    3% |█                               | 1.1MB 13.7MB/s eta 0:00:03

# %%
# !pip3 list
# Out:
# affine (2.1.0)
# amqp (2.2.2)
# astroid (1.6.1)
# attrs (17.4.0)
# billiard (3.5.0.3)
# bleach (2.1.3)
# boto3 (1.4.3)
# botocore (1.4.93)
# cachetools (2.0.1)
# celery (4.1.0)
# certifi (2018.1.18)
# cf-units (1.2.0)
# chardet (3.0.4)
# click (6.7)
# click-plugins (1.0.3)
# cligj (0.4.0)
# cloudpickle (0.5.2)
# compliance-checker (3.1.1)
# coverage (4.5.1)
# cycler (0.10.0)
# dask (0.17.0)
# datacube (0+unknown, /usr/local/lib/python3.5/dist-packages)
# dc-tests-io (1.0)
# decorator (4.2.1)
# dill (0.2.7.1)
# docutils (0.14)
# entrypoints (0.2.3)
# enum34 (1.1.6)
# GDAL (2.2.3)
# graphviz (0.8.2)
# html5lib (1.0.1)
# hypothesis (3.45.0)
# idna (2.6)
# ipykernel (4.8.2)
# ipython (6.2.1)
# ipython-genutils (0.2.0)
# ipywidgets (7.1.2)
# isodate (0.6.0)
# isort (4.3.4)
# jedi (0.11.1)
# Jinja2 (2.10)
# jmespath (0.9.3)
# jsonschema (2.6.0)
# jupyter (1.0.0)
# jupyter-client (5.2.3)
# jupyter-console (5.2.0)
# jupyter-core (4.4.0)
# kiwisolver (1.0.1)
# kombu (4.1.0)
# ...

# %%
#%pylab notebook
from datacube.storage import masking
from datacube import Datacube
from datetime import datetime
from skimage import exposure
# from scikit_image import exposure
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-3d684ef941ba> in <module>()
#       3 from datacube import Datacube
#       4 from datetime import datetime
# ----> 5 from skimage import exposure
#       6 # from scikit_image import exposure
#
# ImportError: No module named 'skimage'
